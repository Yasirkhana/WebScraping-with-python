# %% [markdown]
# # <center> WEBSCRAPING WITH PYTHON <center>

# %% [markdown]
# ##### So for this project I'm going to use ("https://pythonhow.com/example.html") this example webpage. It is a basic html page and its easy for beginner to uderstand the concept of webscraping

# %%
import requests 
from bs4 import BeautifulSoup    #beautifulSoup 4

# %% [markdown]
# ##### First we have to import the souce code of the website

# %%
#r = requests.get("https://pythonhow.com/example.html")
URL = 'https://www.salariagroup.com/'
page = requests.get(URL)

# %%
c = page.content

# %%
print(c)
# Out:
# b'<head><title>Not Acceptable!</title></head><body><h1>Not Acceptable!</h1><p>An appropriate representation of the requested resource could not be found on this server. This error was generated by Mod_Security.</p></body></html>'

# %%
soup = BeautifulSoup(c,"html.parser")

# %%
print(soup.prettify())
# Out:
# <head>
#  <title>
#   Not Acceptable!
#  </title>
# </head>
# <body>
#  <h1>
#   Not Acceptable!
#  </h1>
#  <p>
#   An appropriate representation of the requested resource could not be found on this server. This error was generated by Mod_Security.
#  </p>
# </body>
